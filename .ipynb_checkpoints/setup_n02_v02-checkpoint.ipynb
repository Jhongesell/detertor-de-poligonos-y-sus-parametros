# %%
ls
# Out:
# models/     setup_n01_v01.ipynb*  setup_n02_v02.ipynb*
# README.md*  setup_n02_v01.ipynb*  src/

# %%
import cv2
import numpy as np

# %%
cap=cv2.VideoCapture(1)
cap=cv2.imread('src/image_n02_v01.png')

# %%
verdeBajo=np.array([50,100,20],np.uint8)
verdeAlto=np.array([70,255,255],np.uint8)

# %%
while True:
    ret, frame=cap.read()
    if ret == True:
        frameHSV=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
        maskGreen=cv2.inRange(frameHSV,verdeBajo,verdeAlto)
        maskGreenvis=cv2.bitwise_and(frame,frame, mask=maskGreen)
        contornos,_=cv2.findContours(maskGreen,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
        for c in contornos:
            area=cv2.contourArea(c)
            if area > 3000:
                cv2.drawContours(frame,[c],0,(205,0,255),3)
                print("El área es: "+str(area)+" pixeles**2.")
        cv2.imshow('maskGreen',maskGreen)
        cv2.imshow('frame',frame)
        cv2.imshow('maskGreenvis',maskGreenvis)
        if cv2.waitKey(1) & 0xFF == ord('s'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# El área es: 5249.5 pixeles**2.
# El área es: 4282.0 pixeles**2.
# El área es: 3974.5 pixeles**2.
# El área es: 3820.5 pixeles**2.
# El área es: 3025.5 pixeles**2.
# El área es: 3962.5 pixeles**2.
# El área es: 4324.0 pixeles**2.
# El área es: 4650.5 pixeles**2.
# El área es: 4522.0 pixeles**2.
# El área es: 4082.5 pixeles**2.
# El área es: 3891.5 pixeles**2.
# El área es: 3518.0 pixeles**2.
# El área es: 3193.5 pixeles**2.
# El área es: 3216.0 pixeles**2.
# El área es: 3456.5 pixeles**2.
# El área es: 3956.5 pixeles**2.
# El área es: 4131.0 pixeles**2.
# El área es: 4104.5 pixeles**2.
# El área es: 4072.0 pixeles**2.
# El área es: 4113.5 pixeles**2.
# El área es: 4116.0 pixeles**2.
# El área es: 4076.5 pixeles**2.
# El área es: 4030.5 pixeles**2.
# El área es: 4150.0 pixeles**2.
# El área es: 4136.5 pixeles**2.
# El área es: 4124.0 pixeles**2.
# El área es: 4251.0 pixeles**2.
# El área es: 4206.0 pixeles**2.
# El área es: 4172.5 pixeles**2.
# El área es: 4211.5 pixeles**2.
# El área es: 4299.0 pixeles**2.
# El área es: 4236.0 pixeles**2.
# El área es: 4284.5 pixeles**2.
# El área es: 4229.5 pixeles**2.
# El área es: 4224.0 pixeles**2.
# El área es: 4213.0 pixeles**2.
# El área es: 4304.0 pixeles**2.
# El área es: 4319.0 pixeles**2.
# El área es: 4355.0 pixeles**2.
# El área es: 4267.0 pixeles**2.
# El área es: 4242.5 pixeles**2.
# El área es: 4213.5 pixeles**2.
# El área es: 4226.0 pixeles**2.
# El área es: 4243.0 pixeles**2.
# El área es: 4358.0 pixeles**2.
# El área es: 4242.0 pixeles**2.
# El área es: 4360.5 pixeles**2.
# El área es: 4306.0 pixeles**2.
# El área es: 4297.0 pixeles**2.
# El área es: 4270.0 pixeles**2.
# El área es: 4325.5 pixeles**2.
# El área es: 4243.0 pixeles**2.
# El área es: 4317.5 pixeles**2.
# El área es: 4479.5 pixeles**2.
# El área es: 4275.0 pixeles**2.
# El área es: 3182.5 pixeles**2.
# El área es: 3011.5 pixeles**2.
# El área es: 3066.0 pixeles**2.
# El área es: 3169.0 pixeles**2.
# El área es: 3339.5 pixeles**2.
# El área es: 3511.5 pixeles**2.
# El área es: 3629.0 pixeles**2.
# El área es: 3759.5 pixeles**2.
# El área es: 3806.5 pixeles**2.
# El área es: 3872.0 pixeles**2.
# El área es: 3896.5 pixeles**2.
# El área es: 3943.0 pixeles**2.
# El área es: 3953.5 pixeles**2.
# El área es: 3970.5 pixeles**2.
# El área es: 4005.5 pixeles**2.
# El área es: 4013.5 pixeles**2.
# El área es: 4000.0 pixeles**2.
# El área es: 4031.5 pixeles**2.
# El área es: 4032.5 pixeles**2.
# El área es: 4001.0 pixeles**2.
# El área es: 3994.0 pixeles**2.
# El área es: 4000.5 pixeles**2.
# El área es: 3990.0 pixeles**2.
# El área es: 3983.0 pixeles**2.
# El área es: 3962.5 pixeles**2.
# El área es: 3981.0 pixeles**2.
# El área es: 3974.0 pixeles**2.
# El área es: 4022.0 pixeles**2.
# El área es: 4031.0 pixeles**2.
# El área es: 4051.0 pixeles**2.
# El área es: 4007.5 pixeles**2.
# El área es: 4016.0 pixeles**2.
# El área es: 4033.0 pixeles**2.
# El área es: 4079.5 pixeles**2.
# El área es: 4073.5 pixeles**2.
# El área es: 4079.0 pixeles**2.
# El área es: 4131.5 pixeles**2.
# El área es: 4138.5 pixeles**2.
# El área es: 4173.0 pixeles**2.
# El área es: 4239.0 pixeles**2.
# El área es: 4238.0 pixeles**2.
# El área es: 4214.5 pixeles**2.
# El área es: 4300.0 pixeles**2.
# El área es: 4275.0 pixeles**2.
# El área es: 4349.0 pixeles**2.
# El área es: 4400.5 pixeles**2.
# El área es: 4418.5 pixeles**2.
# El área es: 5355.5 pixeles**2.
# El área es: 5773.0 pixeles**2.
# El área es: 3064.5 pixeles**2.
# El área es: 3157.0 pixeles**2.
# El área es: 3254.0 pixeles**2.
# El área es: 3342.5 pixeles**2.
# El área es: 3400.0 pixeles**2.
# El área es: 3439.5 pixeles**2.
# El área es: 3431.0 pixeles**2.
# El área es: 3380.5 pixeles**2.
# El área es: 3369.5 pixeles**2.
# El área es: 3390.0 pixeles**2.
# El área es: 3451.0 pixeles**2.
# El área es: 3517.0 pixeles**2.
# El área es: 3544.5 pixeles**2.
# El área es: 3551.0 pixeles**2.
# El área es: 3560.5 pixeles**2.
# El área es: 3604.5 pixeles**2.
# El área es: 3621.5 pixeles**2.
# El área es: 3671.0 pixeles**2.
# El área es: 3715.5 pixeles**2.
# El área es: 3746.5 pixeles**2.
# El área es: 3794.5 pixeles**2.
# El área es: 3818.5 pixeles**2.
# El área es: 3851.5 pixeles**2.
# El área es: 3928.0 pixeles**2.
# El área es: 3932.5 pixeles**2.
# El área es: 3946.0 pixeles**2.
# El área es: 3917.0 pixeles**2.
# El área es: 4007.5 pixeles**2.
# El área es: 4051.0 pixeles**2.
# El área es: 3972.0 pixeles**2.
# El área es: 4041.5 pixeles**2.
# El área es: 4031.0 pixeles**2.
# El área es: 4060.0 pixeles**2.
# El área es: 4086.0 pixeles**2.
# El área es: 4084.0 pixeles**2.
# El área es: 4086.0 pixeles**2.
# El área es: 4049.0 pixeles**2.
# El área es: 4039.0 pixeles**2.
# El área es: 4033.5 pixeles**2.
# El área es: 4041.0 pixeles**2.
# El área es: 4070.5 pixeles**2.
# El área es: 4103.0 pixeles**2.
# El área es: 4101.5 pixeles**2.
# El área es: 4067.0 pixeles**2.
# El área es: 4135.0 pixeles**2.
# El área es: 4110.5 pixeles**2.
# El área es: 4103.0 pixeles**2.
# El área es: 4148.0 pixeles**2.
# El área es: 4134.5 pixeles**2.
# El área es: 4141.5 pixeles**2.
# El área es: 4143.0 pixeles**2.
# El área es: 4103.0 pixeles**2.
# El área es: 4104.0 pixeles**2.
# El área es: 4085.5 pixeles**2.
# El área es: 4088.5 pixeles**2.
# El área es: 4074.0 pixeles**2.
# El área es: 4109.5 pixeles**2.
# El área es: 4087.0 pixeles**2.
# El área es: 4074.0 pixeles**2.
# El área es: 4055.5 pixeles**2.
# El área es: 4030.5 pixeles**2.
# El área es: 4039.5 pixeles**2.
# El área es: 4009.5 pixeles**2.
# El área es: 4084.0 pixeles**2.
# El área es: 4104.0 pixeles**2.
# El área es: 4083.0 pixeles**2.
# El área es: 4048.0 pixeles**2.
# El área es: 3995.5 pixeles**2.
# El área es: 4019.0 pixeles**2.
# El área es: 3939.0 pixeles**2.
# El área es: 3929.0 pixeles**2.
# El área es: 3950.5 pixeles**2.
# El área es: 3982.0 pixeles**2.
# El área es: 3953.0 pixeles**2.
# El área es: 3901.5 pixeles**2.
# El área es: 3912.0 pixeles**2.
# El área es: 3879.5 pixeles**2.
# El área es: 3890.5 pixeles**2.
# El área es: 3920.5 pixeles**2.
# El área es: 3880.5 pixeles**2.
# El área es: 3936.0 pixeles**2.
# El área es: 3911.5 pixeles**2.
# El área es: 3870.0 pixeles**2.
# El área es: 3898.5 pixeles**2.
# El área es: 3790.0 pixeles**2.
# El área es: 3892.5 pixeles**2.
# El área es: 3910.5 pixeles**2.
# El área es: 3900.5 pixeles**2.
# El área es: 3844.5 pixeles**2.
# El área es: 3900.0 pixeles**2.
# El área es: 3845.5 pixeles**2.
# El área es: 3912.5 pixeles**2.
# El área es: 3890.5 pixeles**2.
# El área es: 3794.0 pixeles**2.
# El área es: 3854.0 pixeles**2.
# El área es: 3813.5 pixeles**2.
# El área es: 3849.5 pixeles**2.
# El área es: 3875.0 pixeles**2.
# El área es: 3817.5 pixeles**2.
# El área es: 3801.5 pixeles**2.
# El área es: 3778.0 pixeles**2.
# El área es: 3812.0 pixeles**2.
# El área es: 3816.5 pixeles**2.
# El área es: 3821.0 pixeles**2.
# El área es: 3830.0 pixeles**2.
# El área es: 3788.0 pixeles**2.
# El área es: 3841.0 pixeles**2.
# El área es: 3770.0 pixeles**2.
# El área es: 3794.0 pixeles**2.
# El área es: 3831.0 pixeles**2.
# El área es: 3776.5 pixeles**2.
# El área es: 3806.0 pixeles**2.
# El área es: 3745.5 pixeles**2.
# El área es: 3820.5 pixeles**2.
# El área es: 3755.5 pixeles**2.
# El área es: 3769.5 pixeles**2.
# El área es: 3756.0 pixeles**2.
# El área es: 3759.0 pixeles**2.
# El área es: 3779.0 pixeles**2.
# El área es: 3832.5 pixeles**2.
# El área es: 3788.0 pixeles**2.
# El área es: 3814.5 pixeles**2.
# El área es: 3787.0 pixeles**2.
# El área es: 3859.5 pixeles**2.
# El área es: 3867.5 pixeles**2.
# El área es: 3962.0 pixeles**2.
# El área es: 4105.0 pixeles**2.
# El área es: 4253.5 pixeles**2.
