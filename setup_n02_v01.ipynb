# %%
ls
# Out:
#  El volumen de la unidad C es TI10664900J
#  El n£mero de serie del volumen es: 627E-0588
#
#  Directorio de C:\Users\PEDRO JUAN\Documents\gitworkspace\detertor-de-poligonos-y-sus-parametros
#
# 16/05/2021  21:07    <DIR>          .
# 16/05/2021  21:07    <DIR>          ..
# 09/05/2021  10:20    <DIR>          .ipynb_checkpoints
# 09/05/2021  12:32    <DIR>          .vs
# 09/05/2021  21:31    <DIR>          models
# 09/05/2021  10:20                28 README.md
# 16/05/2021  21:07             5,688 setup_n01_v01.ipynb
# 16/05/2021  20:55             3,528 setup_n02_v01.ipynb
# 16/05/2021  20:56            12,638 setup_n02_v02.ipynb
# 09/05/2021  10:20            11,075 setup_n02_v03.ipynb
# 09/05/2021  10:20    <DIR>          src
#                5 archivos         32,957 bytes
#                6 dirs  337,884,270,592 bytes libres

# %%
import cv2
import numpy as np

# %%
cap=cv2.VideoCapture(1)

# %%
verdeBajo=np.array([50,100,20],np.uint8)
verdeAlto=np.array([70,255,255],np.uint8)

# %%
while True:
    ret, frame=cap.read()
    if ret == True:
        frameHSV=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
        maskGreen=cv2.inRange(frameHSV,verdeBajo,verdeAlto)
        maskGreenvis=cv2.bitwise_and(frame,frame, mask=maskGreen)
        contornos,_=cv2.findContours(maskGreen,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
        for c in contornos:
            area=cv2.contourArea(c)
            if area > 3000:
                cv2.drawContours(frame,[c],0,(205,0,255),3)
                print("El área es: "+str(area)+" pixeles**2.")
        cv2.imshow('maskGreen',maskGreen)
        cv2.imshow('frame',frame)
        cv2.imshow('maskGreenvis',maskGreenvis)
        if cv2.waitKey(1) & 0xFF == ord('s'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# El área es: 3071.5 pixeles**2.
# El área es: 24480.5 pixeles**2.
# El área es: 36924.5 pixeles**2.
# El área es: 47845.0 pixeles**2.
# El área es: 54990.5 pixeles**2.
# El área es: 54990.5 pixeles**2.
# El área es: 38609.0 pixeles**2.
# El área es: 9698.5 pixeles**2.
# El área es: 13147.5 pixeles**2.
# El área es: 9775.0 pixeles**2.
# El área es: 6883.5 pixeles**2.
# El área es: 3843.0 pixeles**2.
# El área es: 10567.0 pixeles**2.
# El área es: 4890.5 pixeles**2.
# El área es: 7342.5 pixeles**2.
# El área es: 4438.0 pixeles**2.
# El área es: 7444.5 pixeles**2.
# El área es: 3338.5 pixeles**2.
# El área es: 7479.5 pixeles**2.
# El área es: 4236.0 pixeles**2.
# El área es: 7445.5 pixeles**2.
# El área es: 3434.0 pixeles**2.
# El área es: 7304.5 pixeles**2.
# El área es: 3525.0 pixeles**2.
# El área es: 7125.5 pixeles**2.
# El área es: 3759.0 pixeles**2.
# El área es: 7302.0 pixeles**2.
# El área es: 3759.0 pixeles**2.
# El área es: 7302.0 pixeles**2.
# El área es: 4265.5 pixeles**2.
# El área es: 7796.5 pixeles**2.
# El área es: 5311.5 pixeles**2.
# El área es: 8092.0 pixeles**2.
# El área es: 8269.5 pixeles**2.
# El área es: 7755.5 pixeles**2.
# El área es: 8457.0 pixeles**2.
# El área es: 9052.5 pixeles**2.
# El área es: 18887.0 pixeles**2.
# El área es: 19921.0 pixeles**2.
# El área es: 21598.5 pixeles**2.
# El área es: 22863.5 pixeles**2.
# El área es: 5968.5 pixeles**2.
# El área es: 22172.5 pixeles**2.
# El área es: 40885.0 pixeles**2.
# El área es: 54823.5 pixeles**2.
# El área es: 54823.5 pixeles**2.
# El área es: 64712.5 pixeles**2.
# El área es: 65955.0 pixeles**2.
# El área es: 65219.5 pixeles**2.
# El área es: 54708.5 pixeles**2.
# El área es: 53697.5 pixeles**2.
# El área es: 53863.0 pixeles**2.
# El área es: 56267.5 pixeles**2.
# El área es: 55971.0 pixeles**2.
# El área es: 58075.0 pixeles**2.
# El área es: 59261.0 pixeles**2.
# El área es: 57808.0 pixeles**2.
# El área es: 57808.0 pixeles**2.
# El área es: 56576.5 pixeles**2.
# El área es: 57457.5 pixeles**2.
# El área es: 55768.5 pixeles**2.
# El área es: 53911.5 pixeles**2.
# El área es: 53521.5 pixeles**2.
# El área es: 53048.0 pixeles**2.
# El área es: 56323.0 pixeles**2.
# El área es: 53280.5 pixeles**2.
# El área es: 47688.0 pixeles**2.
# El área es: 41361.0 pixeles**2.
# El área es: 53814.0 pixeles**2.
# El área es: 53814.0 pixeles**2.
# El área es: 57539.5 pixeles**2.
# El área es: 51941.5 pixeles**2.
# El área es: 53873.5 pixeles**2.
# El área es: 54877.5 pixeles**2.
# El área es: 54673.0 pixeles**2.
# El área es: 52508.5 pixeles**2.
# El área es: 52045.0 pixeles**2.
# El área es: 4500.0 pixeles**2.
# El área es: 49131.5 pixeles**2.
# El área es: 50226.5 pixeles**2.
# El área es: 50975.5 pixeles**2.
# El área es: 50820.5 pixeles**2.
# El área es: 50820.5 pixeles**2.
# El área es: 44669.0 pixeles**2.
# El área es: 47736.0 pixeles**2.
# El área es: 42385.5 pixeles**2.
# El área es: 40530.0 pixeles**2.
# El área es: 46620.5 pixeles**2.
# El área es: 38747.5 pixeles**2.
# El área es: 38477.5 pixeles**2.
# El área es: 37912.0 pixeles**2.
# El área es: 45473.0 pixeles**2.
# El área es: 36322.5 pixeles**2.
# El área es: 40940.0 pixeles**2.
# El área es: 40940.0 pixeles**2.
# El área es: 42311.0 pixeles**2.
# El área es: 42168.5 pixeles**2.
# El área es: 39920.5 pixeles**2.
# El área es: 39912.5 pixeles**2.
# El área es: 32949.5 pixeles**2.
# El área es: 41772.5 pixeles**2.
# El área es: 39943.5 pixeles**2.
# El área es: 41285.5 pixeles**2.
# El área es: 41188.0 pixeles**2.
# El área es: 41084.5 pixeles**2.
# El área es: 31800.5 pixeles**2.
# El área es: 40432.0 pixeles**2.
# El área es: 33994.0 pixeles**2.
# El área es: 39909.0 pixeles**2.
# El área es: 24686.5 pixeles**2.
# El área es: 32456.0 pixeles**2.
# El área es: 3773.5 pixeles**2.
# El área es: 24928.5 pixeles**2.
# El área es: 24878.0 pixeles**2.
# El área es: 3216.5 pixeles**2.
# El área es: 24081.5 pixeles**2.
# El área es: 4732.5 pixeles**2.
# El área es: 26303.0 pixeles**2.
# El área es: 28116.5 pixeles**2.
# El área es: 32154.5 pixeles**2.
# El área es: 23182.0 pixeles**2.
# El área es: 6719.0 pixeles**2.
# El área es: 30399.5 pixeles**2.
# El área es: 43697.0 pixeles**2.
# El área es: 30093.0 pixeles**2.
# El área es: 41998.5 pixeles**2.
# El área es: 41207.0 pixeles**2.
# El área es: 44807.5 pixeles**2.
# El área es: 40334.0 pixeles**2.
# El área es: 42291.5 pixeles**2.
# El área es: 38624.5 pixeles**2.
# El área es: 37298.5 pixeles**2.
# El área es: 39714.0 pixeles**2.
# El área es: 34429.5 pixeles**2.
# El área es: 35782.0 pixeles**2.
# El área es: 36905.5 pixeles**2.
# El área es: 34461.5 pixeles**2.
# El área es: 34727.0 pixeles**2.
# El área es: 31429.5 pixeles**2.
# El área es: 30962.0 pixeles**2.
# El área es: 53073.5 pixeles**2.
# El área es: 55119.0 pixeles**2.
# El área es: 47011.5 pixeles**2.
# El área es: 49228.5 pixeles**2.
# El área es: 49161.0 pixeles**2.
# El área es: 49165.0 pixeles**2.
# El área es: 48781.0 pixeles**2.
# El área es: 45573.0 pixeles**2.
# El área es: 47375.5 pixeles**2.
# El área es: 46199.5 pixeles**2.
# El área es: 45716.0 pixeles**2.
# El área es: 48612.5 pixeles**2.
# El área es: 46142.0 pixeles**2.
# El área es: 45292.0 pixeles**2.
# El área es: 44444.0 pixeles**2.
# El área es: 48380.0 pixeles**2.
# El área es: 44509.0 pixeles**2.
# El área es: 43286.5 pixeles**2.
# El área es: 45720.0 pixeles**2.
# El área es: 43393.0 pixeles**2.
# El área es: 45820.0 pixeles**2.
# El área es: 42880.0 pixeles**2.
# El área es: 40806.5 pixeles**2.
# El área es: 43509.0 pixeles**2.
# El área es: 41100.5 pixeles**2.
# El área es: 40883.0 pixeles**2.
# El área es: 4260.5 pixeles**2.
# El área es: 36898.5 pixeles**2.
# El área es: 40998.5 pixeles**2.
# El área es: 40031.0 pixeles**2.
# El área es: 41029.5 pixeles**2.
# El área es: 35656.5 pixeles**2.
# El área es: 37320.5 pixeles**2.
# El área es: 36908.5 pixeles**2.
# El área es: 36590.5 pixeles**2.
# El área es: 36340.5 pixeles**2.
# El área es: 35903.5 pixeles**2.
# El área es: 34403.0 pixeles**2.
# El área es: 36657.0 pixeles**2.
# El área es: 33349.5 pixeles**2.
# El área es: 32951.0 pixeles**2.
# El área es: 36404.0 pixeles**2.
# El área es: 37245.5 pixeles**2.
# El área es: 36329.0 pixeles**2.
# El área es: 33202.0 pixeles**2.
# El área es: 36119.0 pixeles**2.
# El área es: 34953.5 pixeles**2.
# El área es: 35508.5 pixeles**2.
# El área es: 35508.5 pixeles**2.
# El área es: 36402.0 pixeles**2.
# El área es: 35339.0 pixeles**2.
# El área es: 35726.5 pixeles**2.
# El área es: 37727.0 pixeles**2.
# El área es: 33300.5 pixeles**2.
# El área es: 32930.5 pixeles**2.
# El área es: 37324.0 pixeles**2.
# El área es: 32334.0 pixeles**2.
# El área es: 25987.5 pixeles**2.
# El área es: 33537.0 pixeles**2.
# El área es: 36323.0 pixeles**2.
# El área es: 36323.0 pixeles**2.
# El área es: 33100.0 pixeles**2.
# El área es: 34743.0 pixeles**2.
# El área es: 32184.0 pixeles**2.
# El área es: 32966.0 pixeles**2.
# El área es: 40043.5 pixeles**2.
# El área es: 35841.5 pixeles**2.
# El área es: 38189.0 pixeles**2.
# El área es: 36030.5 pixeles**2.
# El área es: 36181.0 pixeles**2.
# El área es: 30787.5 pixeles**2.
# El área es: 32114.0 pixeles**2.
# El área es: 35380.5 pixeles**2.
# El área es: 33049.5 pixeles**2.
# El área es: 32739.0 pixeles**2.
# El área es: 32018.5 pixeles**2.
# El área es: 33563.5 pixeles**2.
# El área es: 30153.0 pixeles**2.
# El área es: 29029.5 pixeles**2.
# El área es: 28368.0 pixeles**2.
# El área es: 31336.5 pixeles**2.
# El área es: 28534.5 pixeles**2.
# El área es: 33048.0 pixeles**2.
# El área es: 33048.0 pixeles**2.
# El área es: 28721.5 pixeles**2.
# El área es: 29361.5 pixeles**2.
# El área es: 29657.0 pixeles**2.
# El área es: 27476.0 pixeles**2.
# El área es: 30933.5 pixeles**2.
# El área es: 27966.5 pixeles**2.
# El área es: 33903.0 pixeles**2.
# El área es: 28545.5 pixeles**2.
# El área es: 30970.5 pixeles**2.
# El área es: 28341.0 pixeles**2.
# El área es: 28266.0 pixeles**2.
# El área es: 28266.0 pixeles**2.
# El área es: 28388.0 pixeles**2.
# El área es: 25869.0 pixeles**2.
# El área es: 27622.0 pixeles**2.
# El área es: 27408.0 pixeles**2.
# El área es: 27945.5 pixeles**2.
# El área es: 28746.0 pixeles**2.
# El área es: 28156.5 pixeles**2.
# El área es: 30871.5 pixeles**2.
# El área es: 25324.5 pixeles**2.
# El área es: 26350.5 pixeles**2.
# El área es: 26608.0 pixeles**2.
# El área es: 28798.0 pixeles**2.
# El área es: 28798.0 pixeles**2.
# El área es: 27323.5 pixeles**2.
# El área es: 30958.5 pixeles**2.
# El área es: 29618.5 pixeles**2.
# El área es: 25795.0 pixeles**2.
# El área es: 27525.5 pixeles**2.
# El área es: 27152.5 pixeles**2.
# El área es: 26396.0 pixeles**2.
# El área es: 22119.5 pixeles**2.
# El área es: 21865.0 pixeles**2.
# El área es: 24449.0 pixeles**2.
# El área es: 21555.0 pixeles**2.
# El área es: 21555.0 pixeles**2.
# El área es: 22821.0 pixeles**2.
# El área es: 21460.5 pixeles**2.
# El área es: 21330.0 pixeles**2.
# El área es: 20866.0 pixeles**2.
# El área es: 22771.5 pixeles**2.
# El área es: 18687.5 pixeles**2.
# El área es: 16184.0 pixeles**2.
# El área es: 19187.5 pixeles**2.
# El área es: 15990.5 pixeles**2.
# El área es: 15935.0 pixeles**2.
# El área es: 15067.5 pixeles**2.
# El área es: 15067.5 pixeles**2.
# El área es: 14463.5 pixeles**2.
# El área es: 16933.5 pixeles**2.
# El área es: 14386.5 pixeles**2.
# El área es: 14399.5 pixeles**2.
# El área es: 15357.0 pixeles**2.
# El área es: 15273.5 pixeles**2.
# El área es: 15129.0 pixeles**2.
# El área es: 14298.0 pixeles**2.
# El área es: 16332.5 pixeles**2.
# El área es: 18590.5 pixeles**2.
# El área es: 15145.5 pixeles**2.
# El área es: 15145.5 pixeles**2.
# El área es: 14973.5 pixeles**2.
# El área es: 20490.0 pixeles**2.
# El área es: 15172.5 pixeles**2.
# El área es: 15335.5 pixeles**2.
# El área es: 20314.0 pixeles**2.
# El área es: 16530.0 pixeles**2.
# El área es: 19391.5 pixeles**2.
# El área es: 15303.0 pixeles**2.
# El área es: 15396.0 pixeles**2.
# El área es: 15402.5 pixeles**2.
# El área es: 15188.5 pixeles**2.
# El área es: 15188.5 pixeles**2.
# El área es: 15427.0 pixeles**2.
# El área es: 15526.0 pixeles**2.
# El área es: 18696.5 pixeles**2.
# El área es: 18871.0 pixeles**2.
# El área es: 14201.0 pixeles**2.
# El área es: 18535.0 pixeles**2.
# El área es: 22232.5 pixeles**2.
# El área es: 18948.0 pixeles**2.
# El área es: 17653.0 pixeles**2.
# El área es: 21103.0 pixeles**2.
# El área es: 19503.0 pixeles**2.
# El área es: 3420.0 pixeles**2.
# El área es: 19379.0 pixeles**2.
# El área es: 21091.0 pixeles**2.
# El área es: 20431.5 pixeles**2.
# El área es: 19604.0 pixeles**2.
# El área es: 18808.0 pixeles**2.
# El área es: 20381.0 pixeles**2.
# El área es: 20611.5 pixeles**2.
# El área es: 16789.0 pixeles**2.
# El área es: 15905.5 pixeles**2.
# El área es: 18697.0 pixeles**2.
# El área es: 5316.5 pixeles**2.
# El área es: 15965.0 pixeles**2.
# El área es: 17783.0 pixeles**2.
# El área es: 20457.5 pixeles**2.
# El área es: 16653.0 pixeles**2.
# El área es: 18058.5 pixeles**2.
# El área es: 3098.5 pixeles**2.
# El área es: 20124.0 pixeles**2.
# El área es: 4798.0 pixeles**2.
# El área es: 16063.0 pixeles**2.
# El área es: 21280.0 pixeles**2.
# El área es: 20279.0 pixeles**2.
# El área es: 21180.5 pixeles**2.
# El área es: 14626.5 pixeles**2.
# El área es: 15118.0 pixeles**2.
# El área es: 14922.0 pixeles**2.
# El área es: 21473.5 pixeles**2.
# El área es: 4860.5 pixeles**2.
# El área es: 14817.5 pixeles**2.
# El área es: 7709.0 pixeles**2.
# El área es: 14520.0 pixeles**2.
# El área es: 19304.5 pixeles**2.
# El área es: 21586.5 pixeles**2.
# El área es: 20764.0 pixeles**2.
# El área es: 19856.5 pixeles**2.
# El área es: 22044.5 pixeles**2.
# El área es: 14855.5 pixeles**2.
# El área es: 19266.5 pixeles**2.
# El área es: 5029.0 pixeles**2.
# El área es: 14465.5 pixeles**2.
# El área es: 3269.0 pixeles**2.
# El área es: 15006.0 pixeles**2.
# El área es: 19101.5 pixeles**2.
# El área es: 22037.0 pixeles**2.
# El área es: 16561.0 pixeles**2.
# El área es: 16862.5 pixeles**2.
# El área es: 19229.0 pixeles**2.
# El área es: 14153.0 pixeles**2.
# El área es: 20544.0 pixeles**2.
# El área es: 5340.0 pixeles**2.
# El área es: 14603.5 pixeles**2.
# El área es: 19166.5 pixeles**2.
# El área es: 18183.0 pixeles**2.
# El área es: 4090.5 pixeles**2.
# El área es: 14608.5 pixeles**2.
# El área es: 3178.0 pixeles**2.
# El área es: 17244.0 pixeles**2.
# El área es: 21326.5 pixeles**2.
# El área es: 7540.0 pixeles**2.
# El área es: 16128.0 pixeles**2.
# El área es: 22102.0 pixeles**2.
# El área es: 13605.5 pixeles**2.
# El área es: 3135.0 pixeles**2.
# El área es: 13620.5 pixeles**2.
# El área es: 13859.0 pixeles**2.
# El área es: 13745.5 pixeles**2.
# El área es: 13616.5 pixeles**2.
# El área es: 13534.5 pixeles**2.
# El área es: 13693.0 pixeles**2.
# El área es: 13806.0 pixeles**2.
# El área es: 3469.0 pixeles**2.
# El área es: 13824.0 pixeles**2.
# El área es: 13883.0 pixeles**2.
# El área es: 4299.5 pixeles**2.
# El área es: 13927.0 pixeles**2.
# El área es: 13878.5 pixeles**2.
# El área es: 15436.0 pixeles**2.
# El área es: 3749.5 pixeles**2.
# El área es: 13826.0 pixeles**2.
# El área es: 13823.5 pixeles**2.
# El área es: 13797.5 pixeles**2.
# El área es: 13895.0 pixeles**2.
# El área es: 14112.5 pixeles**2.
# El área es: 13880.5 pixeles**2.
# El área es: 3858.0 pixeles**2.
# El área es: 15962.5 pixeles**2.
# El área es: 3027.5 pixeles**2.
# El área es: 13934.0 pixeles**2.
# El área es: 15482.5 pixeles**2.
# El área es: 13719.5 pixeles**2.
# El área es: 13830.5 pixeles**2.
# El área es: 13790.0 pixeles**2.
# El área es: 13634.5 pixeles**2.
# El área es: 15015.0 pixeles**2.
# El área es: 13616.0 pixeles**2.
# El área es: 13397.0 pixeles**2.
# El área es: 13332.5 pixeles**2.
# El área es: 13297.5 pixeles**2.
# El área es: 13379.5 pixeles**2.
# El área es: 14772.0 pixeles**2.
# El área es: 13270.5 pixeles**2.
# El área es: 12988.5 pixeles**2.
# El área es: 10778.0 pixeles**2.
# El área es: 13479.5 pixeles**2.
# El área es: 13479.5 pixeles**2.
# El área es: 13410.0 pixeles**2.
# El área es: 13442.5 pixeles**2.
# El área es: 13126.5 pixeles**2.
# El área es: 13245.5 pixeles**2.
# El área es: 13294.5 pixeles**2.
# El área es: 13163.5 pixeles**2.
# El área es: 13086.5 pixeles**2.
# El área es: 14729.5 pixeles**2.
# El área es: 13011.5 pixeles**2.
# El área es: 14706.0 pixeles**2.
# El área es: 13083.0 pixeles**2.
# El área es: 13083.0 pixeles**2.
# El área es: 12962.0 pixeles**2.
# El área es: 12805.0 pixeles**2.
# El área es: 12619.0 pixeles**2.
# El área es: 12593.0 pixeles**2.
# El área es: 12580.0 pixeles**2.
# El área es: 12526.5 pixeles**2.
# El área es: 12440.0 pixeles**2.
# El área es: 12628.0 pixeles**2.
# El área es: 12321.5 pixeles**2.
# El área es: 12407.5 pixeles**2.
# El área es: 12186.5 pixeles**2.
# El área es: 12517.0 pixeles**2.
# El área es: 12560.5 pixeles**2.
# El área es: 12549.5 pixeles**2.
# El área es: 12281.0 pixeles**2.
# El área es: 12411.0 pixeles**2.
# El área es: 12588.0 pixeles**2.
# El área es: 12075.5 pixeles**2.
# El área es: 12293.0 pixeles**2.
# El área es: 12541.5 pixeles**2.
# El área es: 12380.5 pixeles**2.
# El área es: 12348.5 pixeles**2.
# El área es: 12284.0 pixeles**2.
# El área es: 12226.0 pixeles**2.
# El área es: 12254.0 pixeles**2.
# El área es: 11979.0 pixeles**2.
# El área es: 12465.0 pixeles**2.
# El área es: 12375.5 pixeles**2.
# El área es: 12354.0 pixeles**2.
# El área es: 12277.0 pixeles**2.
# El área es: 13737.0 pixeles**2.
# El área es: 13465.5 pixeles**2.
# El área es: 12336.0 pixeles**2.
# El área es: 12336.0 pixeles**2.
# El área es: 12334.0 pixeles**2.
# El área es: 7912.0 pixeles**2.
# El área es: 12380.5 pixeles**2.
# El área es: 12264.5 pixeles**2.
# El área es: 12223.5 pixeles**2.
# El área es: 12465.0 pixeles**2.
# El área es: 13437.0 pixeles**2.
# El área es: 12267.0 pixeles**2.
# El área es: 12327.5 pixeles**2.
# El área es: 12095.5 pixeles**2.
# El área es: 7998.0 pixeles**2.
# El área es: 16237.0 pixeles**2.
# El área es: 16237.0 pixeles**2.
# El área es: 13391.0 pixeles**2.
# El área es: 10139.5 pixeles**2.
# El área es: 4580.5 pixeles**2.
# El área es: 3859.5 pixeles**2.
# El área es: 4569.0 pixeles**2.
# El área es: 3961.5 pixeles**2.
# El área es: 9318.0 pixeles**2.
# El área es: 4715.0 pixeles**2.
# El área es: 4411.0 pixeles**2.
# El área es: 4580.5 pixeles**2.
# El área es: 4059.0 pixeles**2.
# El área es: 4512.0 pixeles**2.
# El área es: 3768.0 pixeles**2.
# El área es: 4903.5 pixeles**2.
# El área es: 4060.0 pixeles**2.
# El área es: 4921.5 pixeles**2.
# El área es: 3921.0 pixeles**2.
# El área es: 4671.5 pixeles**2.
# El área es: 3848.5 pixeles**2.
# El área es: 4671.5 pixeles**2.
# El área es: 3848.5 pixeles**2.
# El área es: 4892.5 pixeles**2.
# El área es: 3977.0 pixeles**2.
# El área es: 4088.5 pixeles**2.
# El área es: 4088.5 pixeles**2.
# El área es: 4747.0 pixeles**2.
# El área es: 4110.0 pixeles**2.
# El área es: 4280.5 pixeles**2.
# El área es: 4261.0 pixeles**2.
# El área es: 8931.5 pixeles**2.
# El área es: 4647.5 pixeles**2.
# El área es: 4166.0 pixeles**2.
# El área es: 4567.5 pixeles**2.
# El área es: 4213.0 pixeles**2.
# El área es: 4813.5 pixeles**2.
# El área es: 4095.0 pixeles**2.
# El área es: 4990.5 pixeles**2.
# El área es: 3912.0 pixeles**2.
# El área es: 4870.5 pixeles**2.
# El área es: 3888.5 pixeles**2.
# El área es: 4815.5 pixeles**2.
# El área es: 4243.0 pixeles**2.
# El área es: 4815.5 pixeles**2.
# El área es: 4243.0 pixeles**2.
# El área es: 8790.5 pixeles**2.
# El área es: 4527.0 pixeles**2.
# El área es: 3765.0 pixeles**2.
# El área es: 4540.5 pixeles**2.
# El área es: 4039.0 pixeles**2.
# El área es: 4802.0 pixeles**2.
# El área es: 3745.0 pixeles**2.
# El área es: 4934.0 pixeles**2.
# El área es: 3682.5 pixeles**2.
# El área es: 4544.0 pixeles**2.
# El área es: 3587.5 pixeles**2.
# El área es: 4531.5 pixeles**2.
# El área es: 3513.5 pixeles**2.
# El área es: 3913.0 pixeles**2.
# El área es: 4251.0 pixeles**2.
# El área es: 3471.5 pixeles**2.
# El área es: 3955.0 pixeles**2.
# El área es: 3479.0 pixeles**2.
# El área es: 3603.5 pixeles**2.
# El área es: 3633.0 pixeles**2.
# El área es: 3603.5 pixeles**2.
# El área es: 3633.0 pixeles**2.
# El área es: 3279.5 pixeles**2.
# El área es: 3757.0 pixeles**2.
# El área es: 3524.0 pixeles**2.
# El área es: 8754.5 pixeles**2.
# El área es: 10738.0 pixeles**2.
# El área es: 11177.5 pixeles**2.
# El área es: 10907.5 pixeles**2.
# El área es: 8594.0 pixeles**2.
# El área es: 6697.5 pixeles**2.
# El área es: 11186.0 pixeles**2.
# El área es: 6820.5 pixeles**2.
# El área es: 10901.5 pixeles**2.
# El área es: 6981.5 pixeles**2.
# El área es: 11189.0 pixeles**2.
# El área es: 11401.0 pixeles**2.
# El área es: 11313.0 pixeles**2.
# El área es: 11691.5 pixeles**2.
# El área es: 11852.0 pixeles**2.
# El área es: 11879.5 pixeles**2.
# El área es: 11888.5 pixeles**2.
# El área es: 7485.5 pixeles**2.
# El área es: 11681.0 pixeles**2.
# El área es: 11946.0 pixeles**2.
# El área es: 7572.0 pixeles**2.
# El área es: 8615.0 pixeles**2.
# El área es: 11837.5 pixeles**2.
# El área es: 12029.0 pixeles**2.
# El área es: 12170.0 pixeles**2.
# El área es: 12173.5 pixeles**2.
# El área es: 11950.0 pixeles**2.
# El área es: 12094.0 pixeles**2.
# El área es: 11765.0 pixeles**2.
# El área es: 12270.0 pixeles**2.
# El área es: 7699.5 pixeles**2.
# El área es: 12021.0 pixeles**2.
# El área es: 11999.0 pixeles**2.
# El área es: 13241.0 pixeles**2.
# El área es: 12909.0 pixeles**2.
# El área es: 10146.5 pixeles**2.
# El área es: 12098.0 pixeles**2.
# El área es: 8924.5 pixeles**2.
# El área es: 11685.5 pixeles**2.
# El área es: 11994.0 pixeles**2.
# El área es: 11757.5 pixeles**2.
# El área es: 13316.0 pixeles**2.
# El área es: 11762.0 pixeles**2.
# El área es: 11854.0 pixeles**2.
# El área es: 11914.0 pixeles**2.
# El área es: 11638.5 pixeles**2.
# El área es: 11777.5 pixeles**2.
# El área es: 12949.5 pixeles**2.
# El área es: 11805.0 pixeles**2.
# El área es: 11824.5 pixeles**2.
# El área es: 11965.5 pixeles**2.
# El área es: 11948.0 pixeles**2.
# El área es: 9861.0 pixeles**2.
# El área es: 11918.5 pixeles**2.
# El área es: 12581.5 pixeles**2.
# El área es: 12358.0 pixeles**2.
# El área es: 12904.5 pixeles**2.
# El área es: 11519.5 pixeles**2.
# El área es: 11567.0 pixeles**2.
# El área es: 11874.5 pixeles**2.
# El área es: 9995.5 pixeles**2.
# El área es: 11738.0 pixeles**2.
# El área es: 12119.0 pixeles**2.
# El área es: 11849.5 pixeles**2.
# El área es: 11964.5 pixeles**2.
# El área es: 9839.0 pixeles**2.
# El área es: 9839.0 pixeles**2.
# El área es: 10257.0 pixeles**2.
# El área es: 11902.5 pixeles**2.
# El área es: 12103.0 pixeles**2.
# El área es: 11871.5 pixeles**2.
# El área es: 8419.5 pixeles**2.
# El área es: 11794.0 pixeles**2.
# El área es: 12001.5 pixeles**2.
# El área es: 11954.5 pixeles**2.
# El área es: 11686.0 pixeles**2.
# El área es: 10210.0 pixeles**2.
# El área es: 11886.0 pixeles**2.
# El área es: 11493.0 pixeles**2.
# El área es: 11505.0 pixeles**2.
# El área es: 11184.5 pixeles**2.
# El área es: 11539.0 pixeles**2.
# El área es: 11202.0 pixeles**2.
# El área es: 11048.0 pixeles**2.
# El área es: 11252.0 pixeles**2.
# El área es: 11098.0 pixeles**2.
# El área es: 8874.0 pixeles**2.
# El área es: 9423.0 pixeles**2.
# El área es: 9510.5 pixeles**2.
# El área es: 9510.5 pixeles**2.
# El área es: 10752.0 pixeles**2.
# El área es: 10730.0 pixeles**2.
# El área es: 10847.5 pixeles**2.
# El área es: 9551.5 pixeles**2.
# El área es: 13644.0 pixeles**2.
# El área es: 11684.5 pixeles**2.
# El área es: 10416.0 pixeles**2.
# El área es: 9098.0 pixeles**2.
# El área es: 6274.0 pixeles**2.
